# %% [markdown]
# # Permissions Setup
#
# This notebook defines Unity Catalog permissions required for the PT Frozen Foods project.
#
# It is responsible for granting access to External Locations and other UC objects required by ingestion and processing pipelines.

# %% [markdown]
# ### Permissions Setup — Historical Execution Log
#
# #### Overview
#
# This notebook contains the full sequence of permission grants applied during the setup of the PT Frozen Foods data platform.
#
# #### Important Note
#
# This is a **historical execution log**, not a fully consolidated script.
#
# - Permissions were applied incrementally
# - Some blocks may contain intermediate or redundant steps
# - The final operational state reflects the latest successful executions
#
# #### Purpose
#
# - Provide traceability of permission configuration
# - Document real troubleshooting steps and adjustments
# - Preserve context for governance and debugging
#
# #### Usage Guidance
#
# - Do not execute the entire notebook blindly in new environments
# - For reproducible setup, consider extracting a consolidated version of the final permissions
# - Use this notebook primarily as a reference and audit trail
#
# #### Related Components
#
# - Unity Catalog (UC)
# - External Locations
# - ADF Service Principal
# - Storage Credentials

# %%
# %sql
-- RAW access
GRANT READ FILES
ON EXTERNAL LOCATION `el-ptfrozenfoods-dev`
TO `rm@rmdatasolutions.net`;

-- BRONZE access
GRANT READ FILES, WRITE FILES
ON EXTERNAL LOCATION `el-ptfrozenfoods-bronze-dev`
TO `rm@rmdatasolutions.net`;

# %%
# %sql
-- ========================================
-- ADF SERVICE PRINCIPAL
-- ========================================

-- CATALOG
GRANT USE CATALOG ON CATALOG ptfrozenfoods_dev 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- BRONZE
-- ========================================

GRANT USE SCHEMA ON SCHEMA ptfrozenfoods_dev.bronze 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT SELECT ON SCHEMA ptfrozenfoods_dev.bronze 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MODIFY ON SCHEMA ptfrozenfoods_dev.bronze 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE TABLE ON SCHEMA ptfrozenfoods_dev.bronze 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- SILVER
-- ========================================

GRANT USE SCHEMA ON SCHEMA ptfrozenfoods_dev.silver 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT SELECT ON SCHEMA ptfrozenfoods_dev.silver 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MODIFY ON SCHEMA ptfrozenfoods_dev.silver 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE TABLE ON SCHEMA ptfrozenfoods_dev.silver 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- GOLD
-- ========================================

GRANT USE SCHEMA ON SCHEMA ptfrozenfoods_dev.gold 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT SELECT ON SCHEMA ptfrozenfoods_dev.gold 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MODIFY ON SCHEMA ptfrozenfoods_dev.gold 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE TABLE ON SCHEMA ptfrozenfoods_dev.gold 
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

# %%
# %sql
-- ========================================
-- ADF SERVICE PRINCIPAL - EXTERNAL LOCATION
-- ========================================

GRANT READ FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT WRITE FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

# %%
# %sql
-- ========================================
-- ADF SERVICE PRINCIPAL
-- ========================================

-- Principal
-- adf-ptfrozenfoods-rmds-dev-we
-- Application ID: 83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af


-- ========================================
-- CATALOG
-- ========================================

GRANT USE CATALOG ON CATALOG ptfrozenfoods_dev
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- BRONZE SCHEMA
-- ========================================

GRANT USE SCHEMA ON SCHEMA ptfrozenfoods_dev.bronze
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT SELECT ON SCHEMA ptfrozenfoods_dev.bronze
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MODIFY ON SCHEMA ptfrozenfoods_dev.bronze
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE TABLE ON SCHEMA ptfrozenfoods_dev.bronze
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- SILVER SCHEMA
-- ========================================

GRANT USE SCHEMA ON SCHEMA ptfrozenfoods_dev.silver
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT SELECT ON SCHEMA ptfrozenfoods_dev.silver
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MODIFY ON SCHEMA ptfrozenfoods_dev.silver
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE TABLE ON SCHEMA ptfrozenfoods_dev.silver
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- GOLD SCHEMA
-- ========================================

GRANT USE SCHEMA ON SCHEMA ptfrozenfoods_dev.gold
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT SELECT ON SCHEMA ptfrozenfoods_dev.gold
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MODIFY ON SCHEMA ptfrozenfoods_dev.gold
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE TABLE ON SCHEMA ptfrozenfoods_dev.gold
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- EXTERNAL LOCATION: GENERIC DEV
-- ========================================

GRANT READ FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT WRITE FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE EXTERNAL TABLE ON EXTERNAL LOCATION `el-ptfrozenfoods-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- EXTERNAL LOCATION: BRONZE
-- ========================================

GRANT READ FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-bronze-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT WRITE FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-bronze-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE EXTERNAL TABLE ON EXTERNAL LOCATION `el-ptfrozenfoods-bronze-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- EXTERNAL LOCATION: SILVER
-- ========================================

GRANT READ FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-silver-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT WRITE FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-silver-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE EXTERNAL TABLE ON EXTERNAL LOCATION `el-ptfrozenfoods-silver-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;


-- ========================================
-- EXTERNAL LOCATION: GOLD
-- ========================================

GRANT READ FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-gold-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT WRITE FILES ON EXTERNAL LOCATION `el-ptfrozenfoods-gold-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT CREATE EXTERNAL TABLE ON EXTERNAL LOCATION `el-ptfrozenfoods-gold-dev`
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

# %%
# %sql
GRANT MANAGE ON SCHEMA ptfrozenfoods_dev.silver
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;

GRANT MANAGE ON SCHEMA ptfrozenfoods_dev.gold
TO `83f60c2e-b9b4-4bf1-b1ad-5f920c5a21af`;
